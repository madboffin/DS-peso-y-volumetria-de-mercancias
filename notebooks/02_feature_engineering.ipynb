# %%
import os
import json

import pandas as pd
from dotenv import load_dotenv


path = "../data/raw/market_products.csv"

# %% [markdown]
# # Lectura del archivo csv

# %%
dtypes = {
    "sku": str,
    "gtin": str
}
df = pd.read_csv(path, dtype=dtypes)
df.sample()
# Out:
#             sku          gtin  \
# 242  3051626681  463051626689
#
#                                         specifications         brand  \
# 242  [{"name":"Features","value":"Easy Care"},{"nam...  Woman Within
#
#                                            description  \
# 242  Woman Within Women's Plus Size Perfect Printed...
#
#                                           product_name  \
# 242  Woman Within Women's Plus Size Perfect Printed...
#
#                                            review_tags   category_name  \
# 242  ["Fit (106)","Comfort (71)","Color (64)","Leng...  Plus Size Tops
#
#     root_category_name                                         main_image  \
# 242           Clothing  "https://i5.walmartimages.com/seo/Woman-Within...
#
#     unit                                              sizes  \
# 242  NaN  ["1X (22-24)","2X (26-28)","3X (30-32)","4X (3...
#
#                                                 colors  \
# 242  ["Azure Paisley","Black Bandana Paisley","Blac...
#
#                                       other_attributes  \
# 242  [{"name":"Fabric Care Instructions","value":"M...
#
#                                             categories
# 242  ["Clothing","Womens Plus","Plus Size Tops","Pl...

# %% [markdown]
# # Hallazgos iniciales

# %% [markdown]
# * La mayor cantidad de mercancias se relacionan con la ropa
# * SKU es un valor unico que se puede usar en el futuro para referirse a mercancias especificas
# * Hay alguna informacion de unidades pero esta muy incompleta, las unidades son muy inconsistentes
# * Las especificaciones tienen gran cantidad de informacion en strings, que representan listas de diccionarios. Incluyen peso y dimensiones a veces.

# %% [markdown]
# # Asignacion de volumen

# %% [markdown]
# Ideas para el primer acercamiento con complejidad incremental:
# 1. Extraer la informacion de peso y volumen presente
# 2. Uniformar las cantidades
# 3. Completar con valores por defecto (marcar estos productos)
# 3. Desarrollar modelos que predigan peso y volumen (k-nearest neighbors, embeddings y SMV o ANN, uso de APIs de LLMs)

# %%
def safe_parse(x):
    if pd.notna(x):
        return json.loads(x)

def summarize_names(series):
    summary = []
    for specs in series.dropna():
        if isinstance(specs, list):
            for s in specs:
                if isinstance(s, dict) and "name" in s:
                    summary.append(s["name"])
    return summary

df['specifications_parsed'] = df['specifications'].apply(safe_parse)
df['other_attributes_parsed'] = df['other_attributes'].apply(safe_parse)

# %%
def get_weight_or_vol(values: dict, search_key) -> str | None:
    """Busca la etiqueta correcta con peso o volumen en la lista de dictionarios"""
    try:
        return next(d['value'] for d in values if d.get('name') == search_key)
    except StopIteration:
        return None

# %%
# explorando las especificaciones que tienen informacion sobre volumen
col_name = "specifications_parsed"
search_key = "Assembled Product Dimensions (L x W x H)"
has_vol = df[col_name].astype(str).str.contains(search_key, na=False, case=False, regex=False)

# %%
# crear copia de df y usar sku como indice
vols = df.copy()
vols = vols.set_index(keys=["sku"])
has_vol = vols[col_name].astype(str).str.contains(search_key, na=False, case=False, regex=False)

# %%
col_l = "size_l"
col_w = "size_w"
col_h = "size_h"
col_units = "size_units"
# extrae informacion de volumen de la columna de especificaciones
vols_sr = vols[col_name].apply(
    lambda x: get_weight_or_vol(x, search_key=search_key)
)
vols_sr.value_counts().sample(10)
# Out:
# specifications_parsed
# 2.80 x 2.80 x 2.70 Inches       1
# 60.00 x 24.00 x 0.10 Inches     1
# 80.00 x 90.00 x 1.00 Inches     1
# 92.00 x 66.00 x 1.00 Inches     2
# 92.00 x 68.00 x 2.00 Inches     2
# 3.50 x 1.00 x 5.60 Inches       1
# 83.10 x 60.60 x 44.90 Inches    1
# 14.75 x 13.31 x 11.44 Inches    1
# 36.00 x 24.00 x 0.50 Inches     1
# 2.25 x 8.75 x 2.25 Inches       1
# Name: count, dtype: int64

# %%
vols = vols_sr.str.extractall(
    fr"(?P<{col_l}>[\d\.]+) x (?P<{col_w}>[\d\.]+) x (?P<{col_h}>[\d\.]+) (?P<{col_units}>\w+)"
)
vols = vols.droplevel(level=1)  # eliminar indice de match
vols.sample(3)
# Out:
#            size_l size_w size_h size_units
# sku
# 145946079    9.80   2.90   1.90     Inches
# 827790002    2.36   5.12   9.10     Inches
# 5168273880  13.00   8.30   2.50     Inches

# %%
# usar valores numericos
vols[col_h] = pd.to_numeric(vols[col_h])
vols[col_w] = pd.to_numeric(vols[col_w])
vols[col_l] = pd.to_numeric(vols[col_l])

# %% [markdown]
# ## Uniformar volumen

# %%
vols[col_units].value_counts(dropna=False)
# Out:
# size_units
# Inches    282
# Feet        9
# Name: count, dtype: int64

# %%
vols.query("size_units == 'Feet'")
# Out:
#             size_l  size_w  size_h size_units
# sku
# 5354771215    1.00    1.00    1.00       Feet
# 1796059258    0.98    0.66    0.07       Feet
# 1979723992    0.16    0.13    0.03       Feet
# 1980636541    0.16    0.16    0.03       Feet
# 1577779507   10.00   10.00   10.00       Feet
# 968072447     0.43    0.23    0.07       Feet
# 939136581     0.59    0.33    0.10       Feet
# 786691113     1.00    1.00    1.00       Feet
# 178944020     0.66    0.49    0.10       Feet

# %%
# convertir de pies a pulgadas
vols.loc[vols[col_units] == "Feet", [col_h, col_w, col_l]] *= 12

# %%
vols.query("size_units == 'Feet'")
# Out:
#             size_l  size_w  size_h size_units
# sku
# 5354771215   12.00   12.00   12.00       Feet
# 1796059258   11.76    7.92    0.84       Feet
# 1979723992    1.92    1.56    0.36       Feet
# 1980636541    1.92    1.92    0.36       Feet
# 1577779507  120.00  120.00  120.00       Feet
# 968072447     5.16    2.76    0.84       Feet
# 939136581     7.08    3.96    1.20       Feet
# 786691113    12.00   12.00   12.00       Feet
# 178944020     7.92    5.88    1.20       Feet

# %%
vols[col_units] = "in"
df = df.merge(vols.reset_index(), how="left", on="sku")
df.sample()
# Out:
#            sku          gtin  \
# 333  799517514  880021737600
#
#                                         specifications        brand  \
# 333  [{"name":"Features","value":"Hypoallergenic, W...  SGI bedding
#
#                                            description  \
# 333     Enhances Bedroom Decor:&nbsp; Our bedskirt ...
#
#                                           product_name    review_tags  \
# 333  SGI Bedding 14 Inch Wrap Around Bed Skirt | Mi...  ["Color (6)"]
#
#     category_name root_category_name  \
# 333    Bed Skirts               Home
#
#                                             main_image  ...  \
# 333  "https://i5.walmartimages.com/seo/SGI-Bedding-...  ...
#
#                                                  sizes  \
# 333  ["California King- 14\"","Full- 14\"","King- 1...
#
#                                                 colors  \
# 333  ["Black","Blood Red","Burgundy","Chocolate","D...
#
#                                       other_attributes  \
# 333  [{"name":"Fabric Care Instructions","value":"M...
#
#                           categories  \
# 333  ["Home","Bedding","Bed Skirts"]
#
#                                  specifications_parsed  \
# 333  [{'name': 'Features', 'value': 'Hypoallergenic...
#
#                                other_attributes_parsed size_l  size_w  size_h  \
# 333  [{'name': 'Fabric Care Instructions', 'value':...   78.0    80.0    14.0
#
#      size_units
# 333          in
#
# [1 rows x 21 columns]

# %%
mean_vols = df.groupby(["root_category_name"]).agg(
    {
        "size_l": "mean",
        "size_w": "mean",
        "size_h": "mean",
    }
)
mean_vols
# Out:
#                          size_l     size_w     size_h
# root_category_name
# Arts Crafts & Sewing        NaN        NaN        NaN
# Auto & Tires                NaN        NaN        NaN
# Baby                   8.685000   8.300000   7.927500
# Beauty                 5.503333   6.751429  12.579524
# Clothing              10.639574   9.226170   6.263191
# Collectibles           7.000000   5.900000   1.700000
# Electronics            0.980000   2.240000   4.800000
# Food                   4.147273   4.129091   5.817273
# Health and Medicine    4.750000   6.105000   5.215000
# Home                  53.989226  48.401548   7.079484
# Home Improvement       6.313333   6.313333   6.593333
# Household Essentials   3.193333   3.843333   6.503333
# Jewelry                     NaN        NaN        NaN
# Party & Occasions           NaN        NaN        NaN
# Patio & Garden        57.110000  37.096000  39.790000
# Personal Care          3.494545   4.084545   4.920909
# Pets                   6.005556   8.226667   9.105556
# Premium Beauty         3.420000   3.540000   6.100000
# Shop with Purpose      0.660000   1.750000   6.700000
# Sports & Outdoors     11.250000  10.700000   5.200000
# Subscriptions               NaN        NaN        NaN
# Toys                  17.500000  22.500000   2.750000

# %%
# drop rows with na, and round
pathout_json = "../data/processed/mean_volumes.json"
mean_vols.dropna().round(1).to_json(pathout_json, orient="index", indent=4)

# pathout_json = "../data/processed/guessed_volumes.json"
# mean_vols.round(1).to_json(pathout_json, orient="index", indent=4)

# %% [markdown]
# # Asignacion de peso

# %%
# explorando las especificaciones que tienen informacion sobre el peso
col_name = "specifications_parsed"
search_key = "Assembled Product Weight"
col_weight = "weight_value"
col_weight_unit = "weight_unit"
has_weight = df[col_name].astype(str).str.contains(search_key, na=False, case=False)
df[has_weight][col_name].sample().values
# Out:
# array([list([{'name': 'Features', 'value': 'Lightweight'}, {'name': 'Country of Origin - Textiles', 'value': 'Imported'}, {'name': 'Clothing Size', 'value': '2XL'}, {'name': 'Brand', 'value': 'Betiyuaoe'}, {'name': 'Gender', 'value': 'Female'}, {'name': 'Assembled Product Weight', 'value': '0.22 lb'}, {'name': 'Manufacturer', 'value': 'Follure'}, {'name': 'Color', 'value': 'Beige'}, {'name': 'Assembled Product Dimensions (L x W x H)', 'value': '8.27 x 0.39 x 5.51 Inches'}])],
#       dtype=object)

# %%
# crear copia de df y usar sku como indice
weights = df.copy()
weights = weights.set_index(keys=["sku"])
has_weight = weights[col_name].astype(str).str.contains(search_key, na=False, case=False)

# %%
# extraer informacion de peso
weights_sr = weights[col_name].apply(
    lambda x: get_weight_or_vol(x, search_key=search_key)
)
weights = weights_sr.str.extractall(
    rf"(?P<{col_weight}>[\d\.]+) ?(?P<{col_weight_unit}>\w+)"
)
weights[col_weight] = pd.to_numeric(weights[col_weight])
weights[col_weight_unit] = weights[col_weight_unit].str.lower()
weights.sample(3)
# Out:
#                   weight_value weight_unit
# sku        match
# 2348411906 0              8.80          lb
# 37684787   0              0.25      pounds
# 2599647180 0              2.43          lb

# %%
weights[col_weight_unit].value_counts()
# Out:
# weight_unit
# lb        160
# oz         23
# lbs        20
# pounds      5
# ounces      2
# kg          1
# Name: count, dtype: int64

# %%
# uniformar etiquetas
normalize_units = {
    "lbs": "lb",
    "pounds": "lb",
    "ounces": "oz",
}
weights[col_weight_unit] = weights[col_weight_unit].replace(normalize_units)
weights = weights.droplevel(level=1)  # remueve el indice extra de extractall
weights.sample(3)
# Out:
#             weight_value weight_unit
# sku
# 2200709686          6.00          lb
# 45696491            0.52          lb
# 5158180497          0.10          lb

# %%
df = df.merge(weights.reset_index(), how="left", on="sku")
df.sample()
# Out:
#            sku          gtin  \
# 516  939136581  779003679390
#
#                                         specifications      brand  \
# 516  [{"name":"Country of Origin - Textiles","value...  LETDIOSTO
#
#                                            description  \
# 516  LETDIOSTO Women's Plus Size Tops Short Sleeve ...
#
#                                           product_name  \
# 516  LETDIOSTO Women's Plus Size Tops Short Sleeve ...
#
#                                            review_tags   category_name  \
# 516  ["Fit (21)","Material (15)","Color (15)","Size...  Plus Size Tops
#
#     root_category_name                                         main_image  \
# 516           Clothing  "https://i5.walmartimages.com/seo/LETDIOSTO-Wo...
#
#      ...                                   other_attributes  \
# 516  ...  [{"name":"Fabric Care Instructions","value":"R...
#
#                                             categories  \
# 516  ["Clothing","Womens Plus","Plus Size Tops","Pl...
#
#                                  specifications_parsed  \
# 516  [{'name': 'Country of Origin - Textiles', 'val...
#
#                                other_attributes_parsed size_l size_w size_h  \
# 516  [{'name': 'Fabric Care Instructions', 'value':...   7.08   3.96    1.2
#
#      size_units  weight_value  weight_unit
# 516          in          6.26           oz
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Completar peso

# %%
df.query("weight_value.notna()").root_category_name.value_counts()
# Out:
# root_category_name
# Home                    133
# Clothing                 29
# Patio & Garden            9
# Personal Care             8
# Pets                      8
# Health and Medicine       5
# Food                      5
# Home Improvement          3
# Baby                      2
# Beauty                    2
# Household Essentials      2
# Toys                      2
# Collectibles              1
# Arts Crafts & Sewing      1
# Sports & Outdoors         1
# Name: count, dtype: int64

# %%
df.query("weight_value.isna()").specifications.values
# Out:
# array(['[{"name":"Features","value":"Easy Care"},{"name":"Fabric Content","value":"95% Polyester"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Catherines"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Brand","value":"SANMADROLA"},{"name":"Material","value":"70% Cotton and 30% Polyester Fibers"},{"name":"Manufacturer Part Number","value":"WM2-GTSFT01L2-HUI-L"},{"name":"Color","value":"Gray"},{"name":"Manufacturer","value":"SANMADROLA"}]',
#        '[{"name":"Features","value":"Lightweight, Stretch Fabric, Shaping"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"4XL"},{"name":"Fabric Content","value":"Nylon"},{"name":"Brand","value":"HAWEE"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Black"},{"name":"Manufacturer","value":"HAWEE"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"5"},{"name":"Fabric Content","value":"100% 60% Cotton / 40% Polyester"},{"name":"Brand","value":"SEGA"},{"name":"Gender","value":"Female"},{"name":"Manufacturer","value":"BTX"},{"name":"Color","value":"Purple"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Country of Origin - Textiles","value":"USA or Imported"},{"name":"Clothing Size","value":"L"},{"name":"Brand","value":"Made by Johnny"},{"name":"Gender","value":"Female"},{"name":"Model","value":"WT1063-BROWN-L"},{"name":"Color","value":"WT1063-BROWN"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Brand","value":"wet n wild"}]',
#        '[{"name":"Features","value":"Breathable, Moisture Wicking, UV Protection"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"2XL"},{"name":"Fabric Content","value":"82% Polyester"},{"name":"Brand","value":"TIYOMI"},{"name":"Gender","value":"Female"},{"name":"Color","value":"008-Blue"},{"name":"Manufacturer","value":"TIYOMI"}]',
#        '[{"name":"Brand","value":"Amay\'s"},{"name":"Bed Sheet Type","value":"Fitted Bed Sheets"},{"name":"Piece Count","value":"2"},{"name":"Thread Count","value":"800"},{"name":"Fabric Content","value":"100% Organic Cotton"},{"name":"Features","value":"Soft and cool Surface, Sateen Weave"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"AMAY TEXTILES"},{"name":"Manufacturer Part Number","value":"AT-FITTED-21SLD"},{"name":"Model","value":"AT-FITTED-21SLD"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Assembled Product Dimensions (L x W x H)","value":"9.00 x 8.00 x 3.00 Inches"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Buckle"},{"name":"Age Group","value":"Adult"},{"name":"Shoe Width","value":"Medium"},{"name":"Material","value":"Polyurethane"},{"name":"Manufacturer Part Number","value":"camilanudepu-9"},{"name":"Model","value":"camila"},{"name":"Brand","value":"J. Adams"}]',
#        '[{"name":"Brand","value":"Amay\'s"},{"name":"Bed Sheet Type","value":"Fitted Bed Sheets"},{"name":"Piece Count","value":"2"},{"name":"Thread Count","value":"800"},{"name":"Fabric Content","value":"100% Organic Cotton"},{"name":"Features","value":"Soft and cool Surface, Sateen Weave"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"AMAY TEXTILES"},{"name":"Manufacturer Part Number","value":"AT-FITTED-15SLD"},{"name":"Model","value":"AT-FITTED-15SLD"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Assembled Product Dimensions (L x W x H)","value":"9.00 x 8.00 x 3.00 Inches"}]',
#        '[{"name":"Features","value":"Moisture Wicking, Lightweight, Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"10-12"},{"name":"Brand","value":"RBX"},{"name":"Gender","value":"Male"},{"name":"Color","value":"True Red White"}]',
#        '[{"name":"Features","value":"Comfort Fit"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"L"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"Cotton Blend, 25% Polyester,Spandex"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Female"},{"name":"Clothing Neck Style","value":"Crew Neck&Casual Loose"},{"name":"Brand","value":"YI XIANG RAN"},{"name":"Color","value":"Gray1"},{"name":"Manufacturer","value":"YI XIANG RAN"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"numeric_9"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Slip-On"},{"name":"Color","value":"Black"},{"name":"Age Group","value":"Adult"},{"name":"Material","value":"EVA (Ethylene Vinyl Acetate)"},{"name":"Size","value":"9"},{"name":"Brand","value":"Collections Etc"}]',
#        '[{"name":"Brand","value":"Reebok Work"},{"name":"Gender","value":"Male"},{"name":"Manufacturer Part Number","value":"RB4162"},{"name":"Shoe Category","value":"Men\'s Shoes"},{"name":"Manufacturer","value":"Reebok"},{"name":"Assembled Product Dimensions (L x W x H)","value":"60.00 x 50.00 x 0.01 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Gender","value":"Male"},{"name":"Brand","value":"Jockey"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"S"},{"name":"Fabric Content","value":"Polyester + Spandex"},{"name":"Brand","value":"IDOPIP"},{"name":"Gender","value":"Female"},{"name":"Model","value":"bxh_60662"},{"name":"Color","value":"Purple"},{"name":"Manufacturer","value":"IDOPIP"}]',
#        '[{"name":"Features","value":"Oversized"},{"name":"Clothing Size","value":"M"},{"name":"Fabric Content","value":"90% Polyester"},{"name":"Brand","value":"CRAYNER"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Flower35"},{"name":"Manufacturer","value":"CRAYNER"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Brand","value":"MOSHU"},{"name":"Model","value":"summer womens tops"},{"name":"Manufacturer Part Number","value":"LYFW33"},{"name":"Gender","value":"Female"},{"name":"Clothing Size Group","value":"Women"},{"name":"Color","value":"White"},{"name":"Manufacturer","value":"MOSHU"}]',
#        '[{"name":"Features","value":"Comfort Fit"},{"name":"Clothing Size","value":"3XL"},{"name":"Brand","value":"Fantaslook"},{"name":"Fabric Content","value":"95% polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"fall tops for women"},{"name":"Color","value":"Lake Blue"}]',
#        '[{"name":"Food Allergen Statements","value":"Contains Tree Nuts"},{"name":"Brand","value":"Merci"}]',
#        '[{"name":"Features","value":"Pockets"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Fabric Content","value":"Rayon"},{"name":"Brand","value":"Aiyino"},{"name":"Gender","value":"Female"},{"name":"Model","value":"DA731-SL-XL-Spots"},{"name":"Color","value":"Spots"},{"name":"Manufacturer","value":"Aiyino"}]',
#        '[{"name":"Features","value":"Lined"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XS"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Fabric Content","value":"Polyester + Spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"hct_43565"},{"name":"Color","value":"Black"}]',
#        '[{"name":"Features","value":"Breathable, Stretch"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Color","value":"Black"},{"name":"Clothing Size","value":"L"},{"name":"Fabric Content","value":"95% Cotton"},{"name":"Manufacturer","value":"Innersy Store"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"INNERSY"}]',
#        '[{"name":"Brand","value":"Super Nutrition"},{"name":"Multipack Quantity","value":"1"},{"name":"Count Per Pack","value":"30"},{"name":"Count","value":"30"},{"name":"Vitamin & Supplement Type","value":"Multivitamin Supplements"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Male"},{"name":"Flavor","value":"Unflavored"},{"name":"Manufacturer","value":"Super Nutrition"}]',
#        '[{"name":"Features","value":"Easy Care"},{"name":"Fabric Content","value":"60% Cotton"},{"name":"Brand","value":"Woman Within"},{"name":"Gender","value":"Female"}]',
#        '[{"name":"Features","value":"Elastic Waistband, Durable, Pockets"},{"name":"Clothing Size","value":"L"},{"name":"Fabric Content","value":"65% Polyester, 35% Cotton"},{"name":"Gender","value":"Male"},{"name":"Brand","value":"Chef Code"},{"name":"Model","value":"CC223"},{"name":"Manufacturer","value":"Chef Code"},{"name":"Color","value":"Black"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"US 6"},{"name":"Occasion","value":"Wedding, Daily"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Slip-On"},{"name":"Color","value":"Pink"},{"name":"Age Group","value":"Adult"},{"name":"Material","value":"Mesh"},{"name":"Size","value":"6(37)"},{"name":"Brand","value":"LoyisViDion"},{"name":"Features","value":"Womens Shoes Clearance, Womens Sandals, Clearance under $5.00"}]',
#        '[{"name":"Features","value":"Stretch"},{"name":"Clothing Size","value":"10"},{"name":"Waist Size","value":"6"},{"name":"Size","value":"10"},{"name":"Pant Style","value":"Culottes"},{"name":"Fabric Content","value":"Spandex, Cotton"},{"name":"Brand","value":"Gloria Vanderbilt"},{"name":"Gender","value":"Female"},{"name":"Model","value":"30223736 PM6 10EA R"},{"name":"Color","value":"White"},{"name":"Clothing Size Group","value":"Women"},{"name":"Pant Rise","value":"High"},{"name":"Waist Style","value":"Banded Waist"}]',
#        '[{"name":"Features","value":"Flame Resistant"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"3XL"},{"name":"Brand","value":"BOCOMAL"},{"name":"Gender","value":"Unisex"},{"name":"Color","value":"Navy Blue"}]',
#        '[{"name":"Features","value":"Pockets, Elastic Waistband"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA"},{"name":"Clothing Size","value":"8/9"},{"name":"Brand","value":"Bali"},{"name":"Gender","value":"Female"},{"name":"Model","value":"DF303J"},{"name":"Color","value":"Classic Denim"},{"name":"Manufacturer","value":"Bali"},{"name":"Assembled Product Dimensions (L x W x H)","value":"5.00 x 5.00 x 5.00 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"100% Cotton"},{"name":"Pattern","value":"Graphic Prints"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Character","value":"Yoda"},{"name":"Brand","value":"Star Wars"},{"name":"Color","value":"Kelly Green"}]',
#        '[{"name":"Container Type","value":"Bottle"},{"name":"Manufacturer Part Number","value":"F422"},{"name":"Flavor","value":"Coconut"}]',
#        '[{"name":"Brand","value":"Georgia Boot"},{"name":"Gender","value":"Male"},{"name":"Color","value":"BROWN CAMO"},{"name":"Manufacturer Part Number","value":"GB00655"},{"name":"Shoe Category","value":"Men\'s Shoes"},{"name":"Manufacturer","value":"Georgia Boot"}]',
#        '[{"name":"Features","value":"Wrinkle Resistance, Fade Resistant, Soft Comfortable, Breathable, Durable, Microfiber Bedskirt"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Age Group","value":"Senior, Adult, Toddler, Child"},{"name":"Brand","value":"Dee\'s Collection"},{"name":"Fabric Content","value":"Microfiber"},{"name":"Pattern","value":"Multi Ruffled"},{"name":"Size","value":"Short Queen"},{"name":"Bed Size","value":"Short Queen"},{"name":"Manufacturer Part Number","value":"RT-15MB-CHILD-794"},{"name":"Manufacturer","value":"Dee\'s Collection"},{"name":"Color","value":"Moss"}]',
#        '[{"name":"Features","value":"Hypoallergenic, Wrinkle Resistant, Fade Resistant, Stain Resistant"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Age Group","value":"Adult, Senior, Child"},{"name":"Brand","value":"SGI bedding"},{"name":"Fabric Content","value":"Microfiber"},{"name":"Pattern","value":"Wrap Around"},{"name":"Size","value":"Full- 21\\""},{"name":"Bed Size","value":"Full"},{"name":"Manufacturer Part Number","value":"SGI-WABS21IN-FUCAT308TL"},{"name":"Manufacturer","value":"SGI Bedding"},{"name":"Color","value":"Teal"},{"name":"Assembled Product Dimensions (L x W x H)","value":"54.00 x 75.00 x 21.00 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"90% Cotton, 10% Polyester"},{"name":"Pattern","value":"Graphic Prints"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Character","value":"Batman"},{"name":"Brand","value":"Batman"}]',
#        '[{"name":"Features","value":"Comfort Fit"},{"name":"Country of Origin - Textiles","value":"USA"},{"name":"Color","value":"Pale Blush Pink"},{"name":"Clothing Size","value":"XL"},{"name":"Fabric Content","value":"47% Polyester, 44% Cotton, 9% Rayon"},{"name":"Manufacturer","value":"Hanes"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Hanes"}]',
#        '[{"name":"Features","value":"Asymmetrical hem, Crew neck, 3/4 Sleeves, Soft material"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"4X"},{"name":"Brand","value":"Showmall"},{"name":"Fabric Content","value":"100% 95% Rayon, 5% spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"Navy Blue-4X"},{"name":"Color","value":"H1-Navy Blue"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Clothing Size","value":"6-7"},{"name":"Size","value":"6/7"},{"name":"Brand","value":"Reebok"},{"name":"Model","value":"REB242TX03014"},{"name":"Manufacturer Part Number","value":"REB242TX03014"},{"name":"Gender","value":"Male"},{"name":"Clothing Size Group","value":"Little Boys"},{"name":"Color","value":"True Red Heather"},{"name":"Manufacturer","value":"High Life, LLC"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Brand","value":"Disney"},{"name":"Fabric Content","value":"67% 67% Polyester"},{"name":"Age Group","value":"Child"},{"name":"Color Category","value":"Multicolor"},{"name":"Clothing Size Group","value":"Big Boys"},{"name":"Clothing Style","value":"Casual"},{"name":"Material","value":"67% Polyester, 5% Spandex, 28% Acetate"},{"name":"Gender","value":"Male"},{"name":"Pattern","value":"Pattern"},{"name":"Season","value":"Summer"}]',
#        '[{"name":"Features","value":"Comfort Fit, Lightweight, Cooling"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Brand","value":"voianlimo"},{"name":"Fabric Content","value":"Rayon, 5% Spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"UVO-Z031-Wine Red-M"},{"name":"Color","value":"13-Wine Red"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"Polyester and Spandex"},{"name":"Pattern","value":"Solid"},{"name":"Gender","value":"Female"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Brand","value":"SHIBEVER"},{"name":"Color","value":"#1 Purple"},{"name":"Manufacturer","value":"DR3568"}]',
#        '[{"name":"Features","value":"Sofra Full Length Leggings"},{"name":"Brand","value":"Sofra"},{"name":"Clothing Size Group","value":"Women"},{"name":"Clothing Size","value":"S"},{"name":"Fabric Content","value":"92% Cotton, 8% Spandex"},{"name":"Pant Leg Cut","value":"Slim-Leg"},{"name":"Pant Rise","value":"Mid"},{"name":"Pant Leg Length","value":"Full"},{"name":"Inseam","value":"27 in"},{"name":"Color","value":"2PK-Burgundy/Olive"},{"name":"Country of Origin - Textiles","value":"Imported"}]',
#        '[{"name":"Features","value":"Breathable, Stretch, Colorblock, Casual"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Brand","value":"TIYOMI"},{"name":"Fabric Content","value":"75% Polyester"},{"name":"Gender","value":"Female"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"S"},{"name":"Fabric Content","value":"Lace"},{"name":"Brand","value":"PNTUTB"},{"name":"Gender","value":"Female"},{"name":"Model","value":"B220615B3730"},{"name":"Color","value":"Gray"},{"name":"Manufacturer","value":"Pntutb"}]',
#        '[{"name":"Brand","value":"Eiderdown Décor"},{"name":"Bed Size","value":"Twin/Twin-XL"},{"name":"Material","value":"Cotton, Sateen"},{"name":"Fabric Content","value":"100% Cotton"},{"name":"Color","value":"White"},{"name":"Age Group","value":"Adult"},{"name":"Manufacturer","value":"Eiderdown Décor"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Occasion","value":"Bridal, Everyday, Special Occasion, Wedding"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Ankle Strap"},{"name":"Age Group","value":"Adult"},{"name":"Heel Height","value":"2.00 in"},{"name":"Material","value":"Fabric"},{"name":"Manufacturer Part Number","value":"501714"},{"name":"Model","value":"50-1714"},{"name":"Brand","value":"Bella Vita"}]',
#        '[{"name":"Features","value":"Stretch, Good quality, Dressy Casual, Tunics"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"1X"},{"name":"Brand","value":"CPOKRTWSO"},{"name":"Fabric Content","value":"95% Rayon, 5% Spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"CPO-Z101-Wine Red-1X"},{"name":"Color","value":"Wine Red"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"One Size"},{"name":"Season","value":"All-Season"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Alsol Lamesa"},{"name":"Occasion","value":"This swimsuit cover up is suitable for daily wear,date,party,street wear,beach or holiday wear and make you look more attractive"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Manufacturer","value":"GZXJ"},{"name":"Color","value":"Yellow"}]',
#        '[{"name":"Drink Mix Type","value":"Liquid Water Enhancer"},{"name":"Nutrient Content Claims","value":"Kosher"},{"name":"Food Form","value":"Liquids"},{"name":"Caffeine Designation","value":"Naturally Decaffeinated"},{"name":"Container Material","value":"HDPE"},{"name":"Container Type","value":"Bottle"},{"name":"Food Condition","value":"New"},{"name":"Brand","value":"Stur"}]',
#        '[{"name":"Features","value":"Pockets"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Fabric Content","value":"30% Cotton"},{"name":"Brand","value":"MLANM"},{"name":"Gender","value":"Female"},{"name":"Model","value":"LAN710-C-XL-Floral Yellow White-WFS"},{"name":"Color","value":"LR-Floral Yellow White"},{"name":"Manufacturer","value":"MLANM"}]',
#        '[{"name":"Assembled Product Dimensions (L x W x H)","value":"11.25 x 10.70 x 5.20 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Color","value":"Pink"},{"name":"Brand","value":"Xingqing"},{"name":"Clothing Size","value":"18-24 Months"},{"name":"Fabric Content","value":"95% Cotton Blend"},{"name":"Age Group","value":"Child, Infant"},{"name":"Color Category","value":"Pink"},{"name":"Clothing Size Group","value":"Infant"},{"name":"Clothing Style","value":"Leisure"},{"name":"Material","value":"Cotton Blend"},{"name":"Gender","value":"Female"},{"name":"Pattern","value":"Solid Print"},{"name":"Season","value":"All-Season"}]',
#        '[{"name":"Features","value":"Easy Care"},{"name":"Fabric Content","value":"76% Cotton"},{"name":"Clothing Size Group","value":"Women\'s Plus"},{"name":"Pant Style","value":"Capris"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Roaman\'s"}]',
#        '[{"name":"Features","value":"Non-Slip"},{"name":"Brand","value":"Qishi"},{"name":"Color","value":"Blue"},{"name":"Animal Type","value":"Cat,Dog"},{"name":"Material","value":"Silicone"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Color","value":"White+Hot Pink-Heart"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Clothing Size","value":"5T"},{"name":"Size","value":"5 Years"},{"name":"Fabric Content","value":"Cotton + Polyester"},{"name":"Age Group","value":"Child"},{"name":"Color Category","value":"Pink"},{"name":"Clothing Size Group","value":"Little Girls"},{"name":"Clothing Style","value":"dress up"},{"name":"Material","value":"Cotton + Polyester"},{"name":"Gender","value":"Female"},{"name":"Pattern","value":"Polka Dot Print"}]',
#        '[{"name":"Features","value":"Wicking Athletic Shirts & Tops"},{"name":"Country of Origin - Textiles","value":"USA or Imported"},{"name":"Clothing Size","value":"L"},{"name":"Size","value":"L"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Pattern","value":"Solid"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Brand","value":"A4"},{"name":"Color","value":"Black"},{"name":"Manufacturer","value":"A4"}]',
#        '[{"name":"Features","value":"Quick Dry, High Waisted, Breathable, Tummy Control, Stretch"},{"name":"Country of Origin - Textiles","value":"USA"},{"name":"Color","value":"Green"},{"name":"Clothing Size","value":"3XL"},{"name":"Fabric Content","value":"Polyester"},{"name":"Manufacturer","value":"FAST LA"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Abcnature"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Brand","value":"TIYOMI"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"2XL"},{"name":"Gender","value":"Female"},{"name":"Color","value":"001-Grey"},{"name":"Sleeve Length Style","value":"Long Sleeve"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Fabric Content","value":"95% Polyester"}]',
#        '[{"name":"Dairy Cream Type","value":"Whipping Cream"},{"name":"Animal Welfare Claims","value":"No Claims Apply"},{"name":"Nutrient Content Claims","value":"Trans Fat-Free"},{"name":"Food Condition","value":"Frozen"},{"name":"Container Type","value":"Tub"},{"name":"Container Material","value":"Plastic"},{"name":"Assembled Product Dimensions (L x W x H)","value":"5.88 x 5.88 x 2.70 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"10"},{"name":"Brand","value":"RAW X"},{"name":"Fabric Content","value":"Denim"},{"name":"Gender","value":"Male"},{"name":"Model","value":"BRS-91103"},{"name":"Color","value":"MED BLUE"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Brand","value":"X Ray Jeans"},{"name":"Gender","value":"Male"},{"name":"Fabric Content","value":"50% Nylon,, 30% Viscose,, 20% Polyester"},{"name":"Model","value":"XMW-39111"},{"name":"Manufacturer","value":"XRAY JEANS"}]',
#        '[{"name":"Brand","value":"Whale Flotilla"},{"name":"Bed Size","value":"King"},{"name":"Material","value":"Polyester"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Color","value":"Emerald Green"},{"name":"Features","value":"Reversible"},{"name":"Manufacturer","value":"Whale Flotilla"},{"name":"Manufacturer Part Number","value":"WF-DBL90104-DGN"},{"name":"Country of Origin - Textiles","value":"Imported"}]',
#        '[{"name":"Features","value":"Elastic Waistband, Pockets, Stretch"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"24 Plus"},{"name":"Waist Size","value":"44\\""},{"name":"Pant Style","value":"Bootcut"},{"name":"Fabric Content","value":"Cotton Blend, 21% Rayon, 20% Polyester, 2% Spandex"},{"name":"Brand","value":"Angels Forever Young"},{"name":"Gender","value":"Female"},{"name":"Model","value":"AJ360SCULPTBOT"},{"name":"Color","value":"Orchard"},{"name":"Clothing Size Group","value":"Women\'s Plus"},{"name":"Pant Rise","value":"Mid"},{"name":"Waist Style","value":"Comfort Waist"},{"name":"Jean Wash","value":"Dark Wash"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"90% Cotton, 10% Polyester"},{"name":"Pattern","value":"Graphic Prints"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Character","value":"Tyrannosaurus Rex"},{"name":"Brand","value":"Jurassic Park"},{"name":"Manufacturer","value":"Fifth Sun"}]',
#        '[{"name":"Gender","value":"Male"},{"name":"Brand","value":"Boulder Creek"}]',
#        '[{"name":"Features","value":"Foldable Legs"},{"name":"Assembled Product Dimensions (L x W x H)","value":"23.30 x 16.25 x 13.50 Inches"}]',
#        '[{"name":"Features","value":"Easy Care, Pockets"},{"name":"Brand","value":"Way To Celebrate"},{"name":"Nightgown & Sleepshirt Type","value":"Sleepshirts"},{"name":"Clothing Size Group","value":"Women"},{"name":"Clothing Size","value":"M"},{"name":"Fabric Content","value":"Polyester, Spandex"},{"name":"Color","value":"Brilliant Red"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Clothing Length Style","value":"Sleepwear"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Model","value":"WTC4239954"}]',
#        '[{"name":"Features","value":"Long-Lasting"},{"name":"Brand","value":"Revlon"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.31 x 0.80 x 4.79 Inches"}]',
#        '[{"name":"Brand","value":"Giani Bernini"},{"name":"Casual & Dress Shoe Style","value":"Heels"},{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Material","value":"Manmade"},{"name":"Insole Material","value":"Manmade"},{"name":"Shoe Sole Material","value":"Please See Label For Shoe Sole Material."},{"name":"Toe Style","value":"Round Toe"},{"name":"Heel Height Style","value":"High Heel"},{"name":"Shoe Closure","value":"Ankle Strap"},{"name":"Manufacturer","value":"Giani Bernini"},{"name":"Manufacturer Part Number","value":"VELMAHP"}]',
#        '[{"name":"Clothing Size","value":"Large"},{"name":"Fabric Content","value":"5% SPANDEX, 95% POLYESTER"},{"name":"Brand","value":"Moa Collection"},{"name":"Model","value":"D863"},{"name":"Color","value":"Floral Black White"},{"name":"Manufacturer","value":"MOA COLLECTION"}]',
#        '[{"name":"Features","value":"Easy Care"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Roaman\'s"},{"name":"Fabric Content","value":"100% Cotton"}]',
#        '[{"name":"Size","value":"354ml (12oz)"},{"name":"Shampoo & Conditioner Type","value":"Daily Conditioners"},{"name":"Gender","value":"Unisex"},{"name":"Age Group","value":"Adult"},{"name":"Brand","value":"Aveeno"},{"name":"Hair Type","value":"Dry"},{"name":"Dispenser Style","value":"Squeeze"},{"name":"Multipack Quantity","value":"1"},{"name":"Ingredient Preference","value":"Sulfate-Free, Paraben-Free"},{"name":"Hair Care Key Benefits","value":"Moisturizing"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.68 x 3.45 x 7.24 Inches"}]',
#        '[{"name":"Brand","value":"Wonder Nation"},{"name":"Clothing Size","value":"18 Months"},{"name":"Gender","value":"Male"},{"name":"Color","value":"Teal Sea"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Fabric Content","value":"100% BCI Cotton"},{"name":"Fastener Type","value":"Pull-On"}]',
#        '[{"name":"Hair Type","value":"All Hair Types"},{"name":"Size","value":"1.7 oz"},{"name":"Hair Product Form","value":"Gels"},{"name":"Brand","value":"MIZANI"},{"name":"Assembled Product Dimensions (L x W x H)","value":"3.00 x 3.00 x 5.00 Inches"}]',
#        '[{"name":"Features","value":"press on nails; clip on nails; fake nail; false nails; Stiletto nails,Hallo decoration"},{"name":"Brand","value":"Fofosbeauty"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.00 x 1.00 x 1.00 Feet"}]',
#        '[{"name":"Features","value":"Adjustable, Adjustable Clasp"},{"name":"Clothing Size","value":"32B"},{"name":"Fabric Content","value":"92% Nylon, 8% Spandex, 95% Nylon, 5% Spandex"},{"name":"Brand","value":"No Boundaries"},{"name":"Model","value":"WDC40072"},{"name":"Color","value":"Teal Marina And Deco Turq"},{"name":"Assembled Product Dimensions (L x W x H)","value":"13.00 x 8.30 x 2.50 Inches"}]',
#        '[{"name":"Features","value":"Pockets, Stretch"},{"name":"Clothing Size","value":"32/30"},{"name":"Waist Size","value":"32\\""},{"name":"Pant Style","value":"Skinny Jeans"},{"name":"Fabric Content","value":"90% Cotton, 7% Polyester, 3% Spandex"},{"name":"Brand","value":"G-Style USA"},{"name":"Gender","value":"Male"},{"name":"Model","value":"DL938"},{"name":"Color","value":"Indigo"},{"name":"Clothing Size Group","value":"Men"},{"name":"Pant Rise","value":"Low"},{"name":"Waist Style","value":"Activewear, Streetwear, Workwear"},{"name":"Jean Wash","value":"Raw Denim"}]',
#        '[{"name":"Brand","value":"MaryRuth Organics"},{"name":"Multipack Quantity","value":"1"},{"name":"Count Per Pack","value":"1"},{"name":"Count","value":"1"},{"name":"Vitamin & Supplement Type","value":"Liposomal"},{"name":"Form","value":"Liposomal"},{"name":"Dietary Method","value":"Vegan"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Female"},{"name":"Flavor","value":"Vanilla Peach"},{"name":"Features","value":"Refrigerate Once Opened"},{"name":"Manufacturer","value":"MaryRuth\'s"},{"name":"Nutrient Content Claims","value":"Vegan, Sugar-Free"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"L"},{"name":"Brand","value":"UVPLove"},{"name":"Gender","value":"Female"},{"name":"Fabric Content","value":"95% Softline"},{"name":"Model","value":"UP043-Dark Khaki-L"},{"name":"Color","value":"Dark Khaki"}]',
#        '[{"name":"Brand","value":"JONPONY"},{"name":"Color","value":"Light Brown"},{"name":"Manufacturer Part Number","value":"XL-3268-1-LIGHT BROWN"},{"name":"Manufacturer","value":"JONPONY"},{"name":"Recommended Location","value":"Indoor"},{"name":"Features","value":"Height adjustable"},{"name":"Assembled Product Dimensions (L x W x H)","value":"28.35 x 16.93 x 33.86 Inches"}]',
#        '[{"name":"Clothing Size","value":"38C"},{"name":"Fabric Content","value":"See Description"},{"name":"Brand","value":"Playtex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"1960"},{"name":"Color","value":"Blue"},{"name":"Manufacturer","value":"Playtex"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"L"},{"name":"Brand","value":"Asklazy"},{"name":"Fabric Content","value":"95% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"D Red"},{"name":"Color","value":"D Red"}]',
#        '[{"name":"Features","value":"UV Protection"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Brand","value":"KOOLSOLY"},{"name":"Gender","value":"Unisex"},{"name":"Color","value":"Dark Gray"}]',
#        '[{"name":"Brand","value":"Bali"},{"name":"Gender","value":"Female"},{"name":"Model","value":"DFSTBF"},{"name":"Manufacturer","value":"Bali"}]',
#        '[{"name":"Features","value":"Wrinkle Resistance, Fade Resistant, Soft Comfortable, supima cotton sheet set solid sateen bedding fitted deep pocket luxury extra soft home hotel 4 piece ps bedsheet pillowcase quality mattress softest linens comfort cozy teen long staple, Durable, Sheet Set"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Gender","value":"Unisex"},{"name":"Size","value":"Olympic - Queen"},{"name":"Brand","value":"Dee\'s Collection"},{"name":"Bed Size","value":"Olympic - Queen"},{"name":"Fabric Content","value":"100% Supima Cotton"},{"name":"Manufacturer Part Number","value":"DC_SUPIMACSS_PARNT"},{"name":"Manufacturer","value":"Dee\'s Collection"},{"name":"Color","value":"Golden"}]',
#        '[{"name":"Features","value":"Spray"},{"name":"Brand","value":"Ralph Lauren"},{"name":"Gender","value":"Male"},{"name":"Scent","value":"Mango, Pepper, Roasted Coffee, Indonesian Nutmeg, Rich Woods, Cardamom, Juniper Berry"},{"name":"Fragrance Concentration","value":"Eau de Toilette"},{"name":"Fragrance Strength","value":"Strong"},{"name":"Size","value":"4.2 oz"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.80 x 3.30 x 5.00 Inches"}]',
#        '[{"name":"Features","value":"So many colors that we dare you to find a shade we don`t offer."},{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Size","value":"XL"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"100% Cotton"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Unisex"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Character","value":"T-Shirts"},{"name":"Brand","value":"Hanes"},{"name":"Color","value":"Pale Pink"},{"name":"Manufacturer","value":"Hanes"},{"name":"Assembled Product Dimensions (L x W x H)","value":"13.00 x 8.00 x 1.00 Inches"}]',
#        '[{"name":"Brand","value":"SmartyPants Vitamins"},{"name":"Multipack Quantity","value":"1"},{"name":"Count Per Pack","value":"120"},{"name":"Count","value":"120"},{"name":"Vitamin & Supplement Type","value":"Multivitamins"},{"name":"Form","value":"Gummies"},{"name":"Dietary Method","value":"Non-GMO"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Female"},{"name":"Flavor","value":"Lemon CrÃ¨me, Orange and Blueberry"},{"name":"Features","value":"Folate + D3 + K2/MK7, Excellent source of vitamin A, C, E, B12, B6, B5, K, D, biotin, iodine, and zinc, Omega 3s + CoQ10"},{"name":"Manufacturer","value":"SmartyPants, Inc."},{"name":"Nutrient Content Claims","value":"GMO-Free, No Artificial Colors, No Artificial Flavors"},{"name":"Food Allergen Statements","value":"Free Of: Crustacean Shellfish Egg Fish Milk Peanuts / Peanut Oil Soy / Soybeans Tree Nuts Wheat"},{"name":"Assembled Product Dimensions (L x W x H)","value":"3.00 x 3.00 x 5.38 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"7-8 Years"},{"name":"Fabric Content","value":"90% Polyester + Cotton"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Gender","value":"Female"},{"name":"Model","value":"hct_42013"},{"name":"Color","value":"Dark Green"},{"name":"Manufacturer","value":"IBTOM CASTLE"}]',
#        '[{"name":"Brand","value":"FUBU"},{"name":"Casual & Dress Shoe Style","value":"High-Top Sneakers"},{"name":"Shoe Category","value":"Men\'s Shoes"},{"name":"Shoe Size","value":"9"},{"name":"Shoe Width","value":"Medium"},{"name":"Color","value":"Black"},{"name":"Material","value":"UPPER:PU//OUTSOLE:TPR"},{"name":"Insole Material","value":"UPPER:PU//OUTSOLE:TPR"},{"name":"Shoe Closure","value":"Slip-On"},{"name":"Manufacturer","value":"SHUNCHANG SHOES INDUSTRY CO LTD THE NANAN OF FUJIA"}]',
#        '[{"name":"Features","value":"No"},{"name":"Brand","value":"Maybelline"},{"name":"Color","value":"Caramel Infused"},{"name":"Makeup Form","value":"Liquids"},{"name":"Type","value":"Lip Balms"},{"name":"Manufacturer","value":"Maybelline"},{"name":"Manufacturer Part Number","value":"041554330281"},{"name":"Assembled Product Dimensions (L x W x H)","value":"21.34 x 0.84 x 2.92 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA"},{"name":"Brand","value":"Bali"},{"name":"Manufacturer","value":"Bali"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"S"},{"name":"Brand","value":"SHIBEVER"},{"name":"Fabric Content","value":"Polyester and Spandex"},{"name":"Gender","value":"Female"},{"name":"Color","value":"#1 Purple"}]',
#        '[{"name":"Gender","value":"Unisex"},{"name":"Brand","value":"Pompeii3"},{"name":"Fine or Fashion","value":"Fine"}]',
#        '[{"name":"Brand","value":"Avidlove"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"L"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Grey Blue"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"Rayon"}]',
#        '[{"name":"Features","value":"Easy Care"},{"name":"Fabric Content","value":"60% Cotton"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Roaman\'s"}]',
#        '[{"name":"Features","value":"Seamless"},{"name":"Clothing Size","value":"S"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"Cotton / Polyester"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Brand","value":"Fruit of the Loom"},{"name":"Color","value":"CYBER PINK"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"2X"},{"name":"Brand","value":"Showmall"},{"name":"Fabric Content","value":"95% Rayon, 5% Spandex"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Cream Leopard"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"4XL"},{"name":"Fabric Content","value":"Polyester"},{"name":"Brand","value":"Follure Clothing"},{"name":"Gender","value":"Female"},{"name":"Model","value":"Winter Fall Dresses for Women 21102029050"},{"name":"Color","value":"Hot Pink"},{"name":"Manufacturer","value":"Follure"}]',
#        '[{"name":"Features","value":"Bikini Tops for Women Push up"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Fabric Content","value":"82% Polyester"},{"name":"Brand","value":"Gubotare"},{"name":"Gender","value":"Female"},{"name":"Manufacturer","value":"Gubotare"},{"name":"Color","value":"Hot Pink"}]',
#        '[{"name":"Brand","value":"Cocokind"},{"name":"Features","value":"1 fl oz"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.30 x 1.30 x 4.31 Inches"}]',
#        '[{"name":"Features","value":"Comfort Fit"},{"name":"Clothing Size","value":"2XL"},{"name":"Brand","value":"Fantaslook"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"womens blouses"},{"name":"Color","value":"Blue Floral"}]',
#        '[{"name":"Features","value":"Zenana\'s Dolphin Hem Jersey Short Sleeve Tee Shirts"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Brand","value":"Zenana"},{"name":"Fabric Content","value":"7% Spandex, 93% Rayon"},{"name":"Gender","value":"Female"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Fabric Content","value":"98% 98% polyester and 2% spandex"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"GIRUNS"},{"name":"Manufacturer","value":"GIRUNS"},{"name":"Color","value":"Black"}]',
#        '[{"name":"Brand","value":"Jkerther"},{"name":"Color","value":"2pcs-Red"}]',
#        '[{"name":"Features","value":"Canvas"},{"name":"Brand","value":"Shoes8teen"},{"name":"Casual & Dress Shoe Style","value":"Fashion Sneakers"},{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"8"},{"name":"Shoe Width","value":"Medium"},{"name":"Color","value":"Baby Pink"},{"name":"Material","value":"Hand Made"},{"name":"Insole Color","value":"Pink"},{"name":"Insole Material","value":"man made material"},{"name":"Shoe Sole Material","value":"Rubber"},{"name":"Toe Style","value":"Closed Toe"},{"name":"Heel Height Style","value":"Flat Heel"},{"name":"Heel Height","value":"[CLS]"},{"name":"Shoe Closure","value":"Slip-On, Lace-Up"},{"name":"Footwear Feature","value":"Slip-Resistant"},{"name":"Manufacturer","value":"Shoes8teen"}]',
#        '[{"name":"Features","value":"Quick Drying"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"14"},{"name":"Fabric Content","value":"92% Polyester, 8% Spandex"},{"name":"Brand","value":"Body Glove"},{"name":"Gender","value":"Male"},{"name":"Color","value":"Navy/Yellow"}]',
#        '[{"name":"Brand","value":"Comfortview"},{"name":"Color","value":"Wine"},{"name":"Gender","value":"Female"},{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Age Group","value":"Adult"},{"name":"Manufacturer Part Number","value":"1425100350287mk7-W~7 1/2 W"}]',
#        '[{"name":"Features","value":"Breathable"}]',
#        '[{"name":"Food Allergen Statements","value":"Does not contain any of the major 9 allergens"},{"name":"Food Form","value":"Granules"},{"name":"Brand","value":"Dash"},{"name":"Allergen-Free Statements","value":"Fish-Free"},{"name":"Assembled Product Dimensions (L x W x H)","value":"3.50 x 2.50 x 8.00 Inches"}]',
#        '[{"name":"Shoe Category","value":"Men\'s Shoes"},{"name":"Shoe Size","value":"12"},{"name":"Gender","value":"Male"},{"name":"Shoe Closure","value":"Slingback"},{"name":"Color","value":"Water"},{"name":"Age Group","value":"Adult"},{"name":"Shoe Width","value":"Medium"},{"name":"Material","value":"EVA"},{"name":"Size","value":"12"},{"name":"Manufacturer Part Number","value":"MNRS44SG705"},{"name":"Model","value":"CMS8016WRS"},{"name":"Brand","value":"Rugged Shark"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"9-10 Years"},{"name":"Fabric Content","value":"85% Cotton"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Gender","value":"Female"},{"name":"Model","value":"hct_62290"},{"name":"Color","value":"Pink"},{"name":"Manufacturer","value":"IBTOM CASTLE"}]',
#        '[{"name":"Features","value":"Seamless, Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"5"},{"name":"Brand","value":"GaaiKei"},{"name":"Gender","value":"Female"},{"name":"Model","value":"MNWN-R-5"},{"name":"Color","value":"Nude 6 Pack"},{"name":"Manufacturer","value":"GaaiKei"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"2XL"},{"name":"Sleeve Length Style","value":"Long Sleeve"},{"name":"Fabric Content","value":"93% Rayon Blend"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Female"},{"name":"Clothing Neck Style","value":"Round Neck"},{"name":"Brand","value":"Smallshow"},{"name":"Color","value":"Deep Grey/Deep Green/Navy"},{"name":"Manufacturer","value":"Smallshow"}]',
#        '[{"name":"Features","value":"V-Neck Jersey Long Sleeve Tee Shirts"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"1X"},{"name":"Brand","value":"Zenana"},{"name":"Fabric Content","value":"5% Spandex, 57% Polyester, 38% Rayon"},{"name":"Gender","value":"Female"},{"name":"Color","value":"ASH GREY"}]',
#        '[{"name":"Brand","value":"Amay\'s"},{"name":"Bed Sheet Type","value":"Fitted Bed Sheets"},{"name":"Piece Count","value":"1"},{"name":"Thread Count","value":"800"},{"name":"Fabric Content","value":"100% Organic Cotton"},{"name":"Features","value":"Soft and cool Surface, Sateen Weave"},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"AMAY TEXTILES"},{"name":"Manufacturer Part Number","value":"AT-FITTED-15SLD"},{"name":"Model","value":"AT-FITTED-15SLD"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Assembled Product Dimensions (L x W x H)","value":"9.00 x 8.00 x 3.00 Inches"}]',
#        '[{"name":"Features","value":"Comfort Fit"},{"name":"Brand","value":"Fantaslook"},{"name":"Fabric Content","value":"95% polyester, 5% spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"long sleeve shirts for women"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"5"},{"name":"Occasion","value":"Everyday"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Slip-On"},{"name":"Color","value":"Tan"},{"name":"Age Group","value":"Adult"},{"name":"Heel Height","value":"1.75 in"},{"name":"Shoe Width","value":"Medium"},{"name":"Material","value":"Canvas"},{"name":"Manufacturer Part Number","value":"22336Tan-5"},{"name":"Model","value":"22336Tan-5"},{"name":"Brand","value":"Starbay"},{"name":"Features","value":"Thong"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"50% Cotton, 50% Polyester"},{"name":"Pattern","value":"Graphic Prints"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Character","value":"Joker"},{"name":"Brand","value":"Batman"},{"name":"Manufacturer","value":"Fifth Sun"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Color","value":"White"},{"name":"Brand","value":"Wassery"},{"name":"Clothing Size","value":"0-3 Months"},{"name":"Fabric Content","value":"Cotton Blend"},{"name":"Age Group","value":"Infant"},{"name":"Color Category","value":"White"},{"name":"Clothing Size Group","value":"Infant"},{"name":"Clothing Style","value":"Activewear, Streetwear, Leisure"},{"name":"Material","value":"Cotton Blend"},{"name":"Gender","value":"Unisex"},{"name":"Pattern","value":"Bear Pattern"},{"name":"Season","value":"Fall"}]',
#        '[{"name":"Metal Type","value":"Sterling Silver"},{"name":"Diamond Cut","value":"Round Brilliant Cut"},{"name":"Brand","value":"JeenMata"},{"name":"Gemstone Type","value":"Cubic Zirconia"},{"name":"Gender","value":"Female"},{"name":"Fine or Fashion","value":"Fine"},{"name":"Model","value":"RHJGJnwdbtranmn50"},{"name":"Occasion","value":"anniversay; birthday; engagement; hoilday"},{"name":"Age Group","value":"Adult"}]',
#        '[{"name":"Features","value":"with welt and pockets"},{"name":"Brand","value":"Cueply"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"2X"},{"name":"Size","value":"18-20"},{"name":"Gender","value":"Female"},{"name":"Color","value":"10 FP-Wine Red"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Clothing Neck Style","value":"V-Neck"},{"name":"Fabric Content","value":"Rayon"},{"name":"Fastener Type","value":"elastic waist"},{"name":"Model","value":"CPY190235"}]',
#        '[{"name":"Features","value":"Wrinkle Resistance, Fade Resistant, Soft Comfortable, Breathable, Durable, Microfiber Bedskirt"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Age Group","value":"Senior, Adult, Toddler, Child"},{"name":"Brand","value":"Dee\'s Collection"},{"name":"Fabric Content","value":"Microfiber"},{"name":"Pattern","value":"Ruffled"},{"name":"Size","value":"Short Queen"},{"name":"Bed Size","value":"Short Queen"},{"name":"Manufacturer Part Number","value":"RT-10MB-CHILD-376"},{"name":"Manufacturer","value":"Dee\'s Collection"},{"name":"Color","value":"Lilac"}]',
#        '[{"name":"Features","value":"Seamless"},{"name":"Clothing Size","value":"M"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Fabric Content","value":"Cotton"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Male"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Brand","value":"Fruit of the Loom"},{"name":"Color","value":"KIWI"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"48"},{"name":"Brand","value":"X Ray Jeans"},{"name":"Fabric Content","value":"100% Cotton"},{"name":"Gender","value":"Male"},{"name":"Model","value":"XMS-1618"},{"name":"Color","value":"PLAID WHITE"}]',
# ...
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"6-12 Months"},{"name":"Fabric Content","value":"Polyester + Cotton"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Gender","value":"Female"},{"name":"Model","value":"hct_60490"},{"name":"Color","value":"Blue"},{"name":"Manufacturer","value":"IBTOM CASTLE"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"T-Strap"},{"name":"Age Group","value":"Adult"},{"name":"Material","value":"Fabric/Man Made"},{"name":"Manufacturer Part Number","value":"CABANA"},{"name":"Model","value":"CABANA"},{"name":"Brand","value":"BZEES"}]',
#        '[{"name":"Features","value":"Heart-healthy"},{"name":"Nutrient Content Claims","value":"Gluten-Free"},{"name":"Fruit Type","value":"Apple"},{"name":"Food Preparation Method","value":"In Fruit Juice"},{"name":"Food Condition","value":"Shelf-Stable"},{"name":"Food Form","value":"Liquids"},{"name":"Container Type","value":"Cup"},{"name":"Container Material","value":"Plastic"},{"name":"Assembled Product Dimensions (L x W x H)","value":"2.25 x 8.75 x 2.25 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Features","value":"Top Pro Raglan Long Sleeve Baseball Shirts"}]',
#        '[{"name":"Features","value":"Stretch, Casual"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Brand","value":"Astylish"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"ER5W2519034-103-XL"},{"name":"Color","value":"A CRed103"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"XL"},{"name":"Brand","value":"TIYOMI"},{"name":"Fabric Content","value":"75% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"618"},{"name":"Color","value":"Snakeskin"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Size","value":"6-M"},{"name":"Shoe Size","value":"6"},{"name":"Gender","value":"Female"},{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Brand","value":"Minnetonka"},{"name":"Manufacturer Part Number","value":"40144-GRY"},{"name":"Manufacturer","value":"Minnetonka Moccasin Company, Inc"},{"name":"Color","value":"Gray"}]',
#        '[{"name":"Brand","value":"PJammy"},{"name":"Clothing Size","value":"XXXL"},{"name":"Gender","value":"Male"},{"name":"Color","value":"Scooby Ruh-Roh"},{"name":"Character","value":"Scooby-Doo"},{"name":"Clothing Neck Style","value":"Crew Neck"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Fastener Type","value":"Drawstring"},{"name":"Model","value":"SD4105PTM"},{"name":"Assembled Product Dimensions (L x W x H)","value":"12.00 x 9.00 x 1.00 Inches"}]',
#        '[{"name":"Gender","value":"Unisex"},{"name":"Age Group","value":"Teen, Adult"},{"name":"Features","value":"<li></li>"},{"name":"Brand","value":"American Crew"},{"name":"Hair Type","value":"All Hair Types"},{"name":"Hair Care Key Benefits","value":"Detangling, Shine Enhancing"},{"name":"Dispenser Style","value":"Squeeze"},{"name":"Fluid Ounces","value":"> 7 oz"},{"name":"Assembled Product Dimensions (L x W x H)","value":"3.50 x 2.00 x 7.50 Inches"}]',
#        '[{"name":"Food Allergen Statements","value":"Packaged in a Facility That Also Processes Tree Nuts and Wheat"},{"name":"Brand","value":"Food to Live"},{"name":"Food Form","value":"Powders"}]',
#        '[{"name":"Features","value":"Tummy Control"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Fabric Content","value":"80% Polyamide, 20% Spandex"},{"name":"Brand","value":"Relleciga"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Leopard"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Fabric Content","value":"Polyester"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Hanerdun"}]',
#        '[{"name":"Country of Origin - Textiles","value":"USA or Imported"},{"name":"Clothing Size","value":"4XL"},{"name":"Brand","value":"PNTUTB"},{"name":"Fabric Content","value":"Polyester, Spandex"},{"name":"Gender","value":"Female"},{"name":"Model","value":"A220615A0708"},{"name":"Color","value":"#7-Maroon"}]',
#        '[{"name":"Features","value":"Juniors Plus Blouses & Shirts"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"S"},{"name":"Brand","value":"ASDOKLHQ"},{"name":"Fabric Content","value":"Polyester"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Blue"}]',
#        '[{"name":"Brand","value":"Amay\'s"},{"name":"Bed Sheet Type","value":"Flat Bed Sheets"},{"name":"Piece Count","value":"1"},{"name":"Thread Count","value":"800"},{"name":"Fabric Content","value":"100% Organic Cotton"},{"name":"Features","value":"Provide luxurious comfort and easy care."},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"AMAY TEXTILES"},{"name":"Manufacturer Part Number","value":"AT-FLAT-STRP"},{"name":"Model","value":"AT-FLAT-STRP"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Assembled Product Dimensions (L x W x H)","value":"9.00 x 8.00 x 3.00 Inches"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"M"},{"name":"Brand","value":"UVPLove"},{"name":"Fabric Content","value":"95% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"VS230-Grey-M"},{"name":"Color","value":"Gray"}]',
#        '[{"name":"Features","value":"Round Neck & Round Hem Long Sleeve Tee Shirts"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"1X"},{"name":"Brand","value":"Zenana"},{"name":"Fabric Content","value":"57% Polyester, 38% Rayon, 5% Spandex"},{"name":"Gender","value":"Female"},{"name":"Color","value":"TEAL"}]',
#        '[{"name":"Brand","value":"Comfortview"},{"name":"Color","value":"Houndstooth"},{"name":"Gender","value":"Female"},{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Age Group","value":"Adult"},{"name":"Manufacturer Part Number","value":"1798200350397mk7M~7     M"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Brand","value":"Just Love"},{"name":"Clothing Size","value":"2X Plus"},{"name":"Size","value":"2X Plus"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Tie Dye Bright Spotty"},{"name":"Fabric Content","value":"Cotton"},{"name":"Fastener Type","value":"Drawstring"}]',
#        '[{"name":"Nutrient Content Claims","value":"Vegetarian"},{"name":"Caffeine Designation","value":"Decaffeinated"},{"name":"Coffee Bean Origin","value":"Mysore"},{"name":"Roast Type","value":"Medium"},{"name":"Food Form","value":"Coffee beans"},{"name":"Brand","value":"Fresh Roasted Coffee"},{"name":"Product Line","value":"Roasted Coffee"}]',
#        '[{"name":"Features","value":"Easy to Apply"},{"name":"Brand","value":"L\'Oreal Paris"},{"name":"Assembled Product Dimensions (L x W x H)","value":"2.46 x 3.25 x 6.25 Inches"}]',
#        '[{"name":"Brand","value":"Vulcanodon"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"S"},{"name":"Gender","value":"Male"},{"name":"Color","value":"Red Blue-Plaid"},{"name":"Sleeve Length Style","value":"Long Sleeve"},{"name":"Clothing Neck Style","value":"Notch Neck"},{"name":"Fabric Content","value":"100% Cotton"}]',
#        '[{"name":"Assembled Product Dimensions (L x W x H)","value":"2.42 x 4.37 x 9.18 Inches"}]',
#        '[{"name":"Features","value":"Womens Short Sleeve Cotton Work Shirts"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"L"},{"name":"Brand","value":"Siliteelon"},{"name":"Fabric Content","value":"Cotton Blend"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Burgundy"}]',
#        '[{"name":"Drink Mix Type","value":"Juice Drink Mixes"},{"name":"Nutrient Content Claims","value":"Kosher"},{"name":"Food Form","value":"Powders"},{"name":"Caffeine Designation","value":"Decaffeinated"},{"name":"Container Material","value":"tube"},{"name":"Container Type","value":"Box"},{"name":"Food Condition","value":"Shelf-Stable"},{"name":"Food Allergen Statements","value":"Contains Phenylalanine"},{"name":"Brand","value":"Great Value"},{"name":"Allergen-Free Statements","value":"Gluten-Free, Dairy-Free, Egg-Free, Lactose-Free, Soy/Soybean-Free"},{"name":"Assembled Product Dimensions (L x W x H)","value":"2.69 x 1.31 x 4.50 Inches"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"US6.5/37"},{"name":"Occasion","value":"Vacation"},{"name":"Gender","value":"Unisex"},{"name":"Shoe Closure","value":"Buckle"},{"name":"Color","value":"White"},{"name":"Age Group","value":"Adult"},{"name":"Heel Height","value":"1.25 in"},{"name":"Shoe Width","value":"Medium"},{"name":"Material","value":"PU Leather; Cork"},{"name":"Size","value":"US6.5/37"},{"name":"Brand","value":"BERANMEY"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"5"},{"name":"Brand","value":"Jockey"},{"name":"Gender","value":"Female"},{"name":"Color","value":"Sky Blue/Quilted Prism/Minty Mist"},{"name":"Manufacturer","value":"Jockey"}]',
#        '[{"name":"Features","value":"Lightweight"},{"name":"Country of Origin - Textiles","value":"USA and Imported"},{"name":"Clothing Size","value":"XXL"},{"name":"Brand","value":"Giftesty"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Gender","value":"Female"},{"name":"Model","value":"Rll0629JSXZSS28"},{"name":"Color","value":"Navy"}]',
#        '[{"name":"Features","value":"Wrinkle-Resistant"},{"name":"Clothing Size","value":"34x29"},{"name":"Fabric Content","value":"100% CottonPlain FrontClassic FitExpandable Waist - gives up to three inches of added comfortHaggar\'s Work to Weekend&reg; Khaki slacks are great just about anywhere, from the office to the golf course and everywhere in between. This popular pant is incredibly versatile and matches easily with a button-down shirt, polo, or sports jacket."},{"name":"Gender","value":"Male"},{"name":"Brand","value":"Haggar"},{"name":"Model","value":"5152-0077"},{"name":"Manufacturer","value":"Haggar"},{"name":"Color","value":"British Khaki"}]',
#        '[{"name":"Fabric Content","value":"87% Polyamide"},{"name":"Brand","value":"PARFAIT"},{"name":"Gender","value":"Female"},{"name":"Manufacturer","value":"Parfait"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Brand","value":"Avia"},{"name":"Fabric Content","value":"56.00% Nylon, 41.00% Polyester, 3.00% Spandex"},{"name":"Gender","value":"Female"},{"name":"Sock Size","value":"4-9"},{"name":"Color","value":"Purple"},{"name":"Season","value":"All-Season"},{"name":"Sock Style","value":"Athletic"},{"name":"Age Group","value":"Adult"},{"name":"Sock Rise","value":"No-Show"}]',
#        '[{"name":"Brand","value":"Amay\'s"},{"name":"Bed Size","value":"Queen"},{"name":"Bed Sheet Type","value":"Bed Sheet Sets"},{"name":"Piece Count","value":"4"},{"name":"Thread Count","value":"600"},{"name":"Fabric Content","value":"100% Organic Cotton"},{"name":"Color","value":"Dark Grey {Solid}"},{"name":"Features","value":"Provide luxurious comfort and easy care."},{"name":"Age Group","value":"Adult"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"AMAY TEXTILES"},{"name":"Manufacturer Part Number","value":"AT-24DPSHEEST"},{"name":"Model","value":"AT-24DPSHEEST"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Assembled Product Dimensions (L x W x H)","value":"9.00 x 8.00 x 3.00 Inches"}]',
#        '[{"name":"Shoe Category","value":"Women\'s Shoes"},{"name":"Shoe Size","value":"7"},{"name":"Gender","value":"Female"},{"name":"Shoe Closure","value":"Buckle"},{"name":"Color","value":"Gold Vegan Leather"},{"name":"Age Group","value":"Adult"},{"name":"Shoe Width","value":"Medium"},{"name":"Material","value":"Polyurethane"},{"name":"Brand","value":"J. Adams"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Fabric Content","value":"Nylon and Spandex"},{"name":"Brand","value":"Leading Lady"},{"name":"Gender","value":"Female"},{"name":"Model","value":"19488"},{"name":"Manufacturer","value":"Leading Lady"},{"name":"Assembled Product Dimensions (L x W x H)","value":"13.00 x 8.00 x 1.00 Inches"}]',
#        '[{"name":"Features","value":"Experience the absolute comfort and fit of this jersey tee, Soft, pure, breathable cotton knit, Relaxed fit, but never boxy, Scoopneck tee, Covered neck seam"},{"name":"Clothing Size","value":"L (12/14)"},{"name":"Size","value":"Small-X-Large"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Pattern","value":"Any"},{"name":"Gender","value":"Male"},{"name":"Character","value":"T-Shirts"},{"name":"Brand","value":"Hanes"},{"name":"Color","value":"Ash"},{"name":"Manufacturer","value":"Hanes"},{"name":"Assembled Product Dimensions (L x W x H)","value":"1.00 x 1.00 x 1.00 Inches"}]',
#        '[{"name":"Grain Type","value":"Rice"},{"name":"Nutrient Content Claims","value":"Vegan"},{"name":"Flavor","value":"NOT STATED"},{"name":"Retail Packaging","value":"BAG"},{"name":"Size","value":"12 x 6"},{"name":"Container Type","value":"Bag"},{"name":"Food Form","value":"Fresh"},{"name":"Food Condition","value":"Shelf-Stable"},{"name":"Assembled Product Dimensions (L x W x H)","value":"8.75 x 3.00 x 11.00 Inches"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"16"},{"name":"Age Group","value":"Child"},{"name":"Fabric Content","value":"100% Polyester"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Beverly Hills Polo Club"},{"name":"Color","value":"Khaki Pleated"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Color","value":"Yellow Daisy"},{"name":"Brand","value":"Ibtom Castle"},{"name":"Clothing Size","value":"0-6 Months"},{"name":"Size","value":"0-6 Months"},{"name":"Fabric Content","value":"Cotton + Polyester"},{"name":"Age Group","value":"Newborn"},{"name":"Color Category","value":"Yellow"},{"name":"Clothing Size Group","value":"Newborn"},{"name":"Clothing Style","value":"Casual"},{"name":"Material","value":"Cotton + Polyester"},{"name":"Gender","value":"Female"},{"name":"Pattern","value":"Colorful Polka Dots Print"},{"name":"Season","value":"All-Season"}]',
#        '[{"name":"Features","value":"Breathable"},{"name":"Brand","value":"Feather & Stitch New York"},{"name":"Gender","value":"Unisex"},{"name":"Manufacturer","value":"Feather & Stitch"},{"name":"Manufacturer Part Number","value":"FNSPC500TCWHT_STNDRD"},{"name":"Size","value":"Standard"},{"name":"Thread Count","value":"500"},{"name":"Color","value":"White"}]',
#        '[{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Size","value":"1x"},{"name":"Sleeve Length Style","value":"Short Sleeve"},{"name":"Pattern","value":"Solid Print"},{"name":"Gender","value":"Female"},{"name":"Brand","value":"Jockey"}]',
#        '[{"name":"Features","value":"Reversible"},{"name":"Country of Origin - Textiles","value":"Imported"},{"name":"Clothing Size","value":"1X"},{"name":"Brand","value":"TheLovely"},{"name":"Gender","value":"Female"},{"name":"Clothing Size Group","value":"Women\'s Plus"},{"name":"Color","value":"H Grey"},{"name":"Manufacturer","value":"TheLovely"}]',
#        '[{"name":"Clothing Size","value":"M"},{"name":"Brand","value":"TheLovely"},{"name":"Fabric Content","value":"5% Spandex, Cotton Blend"},{"name":"Gender","value":"Female"},{"name":"Color","value":"GOLDEN MUSTARD"}]'],
#       dtype=object)

# %%
mean_weigts = df.groupby(["root_category_name"]).agg({"weight_value": "mean"})
mean_weigts
# Out:
#                       weight_value
# root_category_name
# Arts Crafts & Sewing      2.880000
# Auto & Tires                   NaN
# Baby                      2.205000
# Beauty                    0.359000
# Clothing                  4.438276
# Collectibles              1.100000
# Electronics                    NaN
# Food                     12.851980
# Health and Medicine       7.000000
# Home                      7.743383
# Home Improvement          8.320000
# Household Essentials      2.292000
# Jewelry                        NaN
# Party & Occasions              NaN
# Patio & Garden           72.208333
# Personal Care             0.970000
# Pets                      5.656950
# Premium Beauty                 NaN
# Shop with Purpose              NaN
# Sports & Outdoors         0.440000
# Subscriptions                  NaN
# Toys                      2.800000

# %%
# drop rows with na, and round
pathout_json = "../data/processed/mean_weights.json"
mean_weigts.dropna().round(1).to_json(pathout_json, orient="index", indent=4)
# pathout_json = "../data/processed/guessed_weights.json"
# mean_weigts.round(1).to_json(pathout_json, orient="index", indent=4)

# %% [markdown]
# Faltantes:
#
# * Normalizar valores y unidades de peso
# * Desarrollar modelos avanzados

# %% [markdown]
# # test api

# %%
from google import genai

load_dotenv()
api_key = os.getenv("api_key")
client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""What is the average weight of a piece of clothing.""",
)
print(response.text)
# Out:
# That's a great question, but there isn't a single, universally "average" weight for a piece of clothing because the weight varies enormously based on several factors:
#
# 1.  **Type of Garment:** A sock is vastly different from a winter coat.
# 2.  **Material:** Cotton, wool, denim, silk, polyester, linen all have different densities and weights.
# 3.  **Size:** A small T-shirt weighs less than an XL T-shirt.
# 4.  **Thickness/Construction:** A light summer dress vs. a heavy, lined winter dress.
#
# However, I can give you some typical ranges for common items:
#
# *   **Very Light (20-100 grams / 0.7-3.5 oz):**
#     *   Underwear, socks, silk scarf, thin camisole.
# *   **Light (100-300 grams / 3.5-10.5 oz):**
#     *   T-shirt, tank top, light blouse, thin pajamas.
# *   **Medium (300-800 grams / 10.5 oz - 1.7 lbs):**
#     *   Jeans, dress shirt, light sweater, summer dress, tracksuit bottoms, light jacket.
# *   **Heavy (800 grams - 2 kg / 1.7 - 4.4 lbs):**
#     *   Denim jacket, thick sweater, winter jeans, medium weight jacket, heavy dress.
# *   **Very Heavy (2 kg+ / 4.4 lbs+):**
#     *   Winter coat, ski jacket, thick wool trench coat.
#
# If you were to take a **very broad "average" from a typical mixed wardrobe**, you might find that many individual items fall in the **300-700 gram (0.7-1.5 lb)** range, largely driven by the prevalence of items like jeans, t-shirts, and light sweaters. But again, this is a highly generalized figure.
#
# **To give you a better answer, it would help to know why you're asking!** (e.g., for shipping costs, laundry load estimation, etc.)
